# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
plt.style.use('seaborn')

# %%
data_set_1 = np.random.randn(600)
plt.hist(data_set_1)
# Out:
# (array([  9.,  28.,  62., 136., 144., 119.,  67.,  25.,   6.,   4.]),
#  array([-2.89546529, -2.25285115, -1.61023702, -0.96762289, -0.32500875,
#          0.31760538,  0.96021952,  1.60283365,  2.24544778,  2.88806192,
#          3.53067605]),
#  <a list of 10 Patch objects>)

# %%
pimas_norm_city = pd.read_csv("pima-data-norm-city.csv")
pimas_filtro = pimas_norm_city[pimas_norm_city["diabetes"] ==True]
pimas_filtro.head(5)
# Out:
#    id  num_preg  glucose_conc  diastolic_bp  insulin   bmi  diab_pred  age  \
# 0   0         6         148.0     72.000000      0.0  33.6      0.627   50
# 2   2         8         183.0     69.112125      0.0  23.3      0.672   32
# 4   4         0         137.0     40.000000    168.0  43.1      2.288   33
# 6   6         3          78.0     50.000000     88.0  31.0      0.248   26
# 8   8         2         197.0     70.000000    543.0  30.5      0.158   53
#
#        skin  diabetes        state    city
# 0  1.379000      True  Maharashtra  Mumbai
# 2  0.809136      True  Maharashtra  Mumbai
# 4  1.379000      True  Maharashtra  Mumbai
# 6  1.260800      True  Maharashtra  Mumbai
# 8  1.773000      True  Maharashtra  Mumbai

# %%
sns.distplot(pimas_norm_city["num_preg"], kde=False, color="y")

# %%
sns.distplot(pimas_norm_city["glucose_conc"])

# %%
fig, ax = plt.subplots()
fig.set_size_inches(18, 6)
sns.boxplot(ax=ax, data= pimas_norm_city)

# %%
sns.boxplot(data= pimas_norm_city["insulin"], color="r")

# %%
sns.boxplot(data= pimas_norm_city["diastolic_bp"], color="y")

# %%
gorjetas = sns.load_dataset("tips")
gorjetas.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
pimas_norm_city.head(5)
# Out:
#    id  num_preg  glucose_conc  diastolic_bp  insulin   bmi  diab_pred  age  \
# 0   0         6         148.0     72.000000      0.0  33.6      0.627   50
# 1   1         1          85.0     66.000000      0.0  26.6      0.351   31
# 2   2         8         183.0     69.112125      0.0  23.3      0.672   32
# 3   3         1          89.0     66.000000     94.0  28.1      0.167   21
# 4   4         0         137.0     40.000000    168.0  43.1      2.288   33
#
#        skin  diabetes        state    city
# 0  1.379000      True  Maharashtra  Mumbai
# 1  1.142600     False  Maharashtra  Mumbai
# 2  0.809136      True  Maharashtra  Mumbai
# 3  0.906200     False  Maharashtra  Mumbai
# 4  1.379000      True  Maharashtra  Mumbai

# %%
sns.lmplot("num_preg","age", pimas_norm_city, x_estimator=np.mean)

# %%
sns.lmplot("age","num_preg", pimas_norm_city, x_estimator=np.mean)

# %%
bilheteria = pd.read_excel("bilheteria.xlsx")
bilheteria
# Out:
#          Data    Bilheteria
# 0  2018-05-01  3.123100e+04
# 1  2018-05-02  4.497264e+04
# 2  2018-05-03  6.476060e+04
# 3  2018-05-04  9.325527e+04
# 4  2018-05-05  1.342876e+05
# 5  2018-05-06  1.933741e+05
# 6  2018-05-07  2.784587e+05
# 7  2018-05-08  4.009806e+05
# 8  2018-05-09  5.774120e+05
# 9  2018-05-10  8.314733e+05
# 10 2018-05-11  1.197322e+06
# 11 2018-05-12  1.724143e+06
# 12 2018-05-13  2.482766e+06

# %%
fig, ax = plt.subplots()
fig.set_size_inches(18, 8)
plt.plot(bilheteria["Data"], bilheteria["Bilheteria"])

# %%
sns.set(style="white")
planetas = sns.load_dataset("planets")
planetas.head(5)
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
g = sns.factorplot(x="year", data=planetas, kind="count",palette="BuPu", size=6,
aspect=1.5)
g.set_xticklabels(step=2)

# %%
bolsa = pd.read_excel("data_akbilgic.xlsx")
bolsa.head(10)
# Out:
#         date  year  month  day month_year       ISE     ISE.1        SP  \
# 0 2009-01-05  2009      1    5     1/2009  0.035754  0.038376 -0.004679
# 1 2009-01-06  2009      1    6     1/2009  0.025426  0.031813  0.007787
# 2 2009-01-07  2009      1    7     1/2009 -0.028862 -0.026353 -0.030469
# 3 2009-01-08  2009      1    8     1/2009 -0.062208 -0.084716  0.003391
# 4 2009-01-09  2009      1    9     1/2009  0.009860  0.009658 -0.021533
# 5 2009-01-12  2009      1   12     1/2009 -0.029191 -0.042361 -0.022823
# 6 2009-01-13  2009      1   13     1/2009  0.015445 -0.000272  0.001757
# 7 2009-01-14  2009      1   14     1/2009 -0.041168 -0.035552 -0.034032
# 8 2009-01-15  2009      1   15     1/2009  0.000662 -0.017268  0.001328
# 9 2009-01-16  2009      1   16     1/2009  0.022037  0.032278  0.007533
#
#         DAX      FTSE    NIKKEI   BOVESPA        EU        EM
# 0  0.002193  0.003894  0.000000  0.031190  0.012698  0.028524
# ...

# %%
bolsa_pivot  = bolsa.pivot("month_year","day","BOVESPA")
bolsa_pivot.head(5)
# Out:
# day               1         2    3         4         5         6         7   \
# month_year
# 1/2009           NaN       NaN  NaN       NaN  0.031190  0.018920 -0.035899
# 1/2010           NaN       NaN  NaN  0.000000  0.002780  0.006938 -0.003938
# 1/2011           NaN       NaN  0.0  0.005076  0.010933 -0.007228 -0.007423
# 10/2009    -0.017364  0.011724  NaN       NaN  0.019379  0.004830 -0.000527
# 10/2010     0.011442       NaN  NaN  0.002219  0.012678 -0.010464 -0.008871
#
# day               8         9         10    ...           22        23  \
# month_year                                  ...
# 1/2009      0.028283 -0.009764       NaN    ...    -0.016982  0.006261
# 1/2010     -0.002672       NaN       NaN    ...    -0.000755       NaN
# 1/2011           NaN       NaN  0.000999    ...          NaN       NaN
# 10/2009     0.017754  0.004866       NaN    ...     0.009862 -0.016404
# 10/2010     0.012663       NaN       NaN    ...    -0.001753       NaN
#
# ...

# %%
fig, ax = plt.subplots()
fig.set_size_inches(18, 8)
sns.heatmap(bolsa_pivot)
